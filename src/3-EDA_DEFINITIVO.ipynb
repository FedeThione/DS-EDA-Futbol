# %% [markdown]
# ![imagen](../src/Data/imagen.jpg)

# %% [markdown]
# **<center><H1>ANÁLISIS EXPLORATORIO DE DATOS (EDA)<H1></center>**

# %% [markdown]
# ## LIBRERIAS A UTILIZAR

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
pd.set_option("display.max_columns", None)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\feder\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## INDICE

# %% [markdown]
# - [**1. TÍTULO**](#1.TÍTULO)
# - [**2. PRIMERA HIPOTESIS**](#2.PRIMERA-HIPÓTESIS)
# - [**3. IMPORTACION DE DATOS**](#3.IMPORTACIÓN-DE-DATOS)
#
#     - [**3.1. Carga del DataSet "edc"**](##3.1.Carga-del-DataSet-"edc")
#     - [**3.2. Carga del DataSet "vec"**](##3.2.Carga-del-DataSet-"vec")
#
# - [**4. EXPLORACIÓN INICIAL**](#4.Exploración-Inicial)
#
#     -  [**4.1. Información general del DataSet "edc"**](#4.1.Información-general-del-DataSet-"edc")
#     -  [**4.2. Información general del DataSet "vec"**](#4.2.Información-general-del-DataSet-"vec")
#
# - [**5. LIMPIEZA DE LOS DATASETS**](#5.Limpieza-de-los-DataSets)
#
# - [**6. ANALISIS DE DATOS**](#6.Análisis-de-datos)
#
#     - [**6.1 Univariante**](#6.1.Univariante)
#     - [**6.2 Bivariante**](#6.2.Bivariante)
#     - [**6.3 Multivariante**](#6.3.Multivariante)

# %% [markdown]
# ## 1. TÍTULO

# %% [markdown]
# *<h3>Exploración y análisis de la correlacion entre la valuacion economica de los mejores clubes europeos de futbol y su desempeño deportivo en la temporada 2020-2021<h3>*

# %% [markdown]
# ## 2. PRIMERA HIPÓTESIS

# %% [markdown]
# Los equipos de futbol de las ligas europeas mas importantes que obtienen mejor rendimiento deportivo son los que están mejor valuados en el mercado.

# %% [markdown]
# ## 3. IMPORTACIÓN DE DATOS

# %% [markdown]
# Los archivos CSV que continen los DataSet a partir de los cuales se realizará el EDA pertenecen a la plataforma online Kaggle.

# %% [markdown]
# | Abreviatura DataSet | Nombre archivo CSV |
# | --------- | --------- |
# | edc | EDA_estadisticas_deportivas_clubes |
# | vec | EDA_valuacion_economica_clubes |

# %% [markdown]
# <h3>3.1 Carga de DataSet "edc"<h3>

# %%
edc = pd.read_csv("../src/Data/EDA_estadisticas_deportivas_clubes.csv")
edc.drop("Unnamed: 0", axis=1, inplace=True)

# %% [markdown]
# | Nombre columna | Descripción |
# | --------- | --------- |
# | equipo | Clubes de fútbol europeos de las ligas más importantes |
# | liga | Liga correspondiente |
# | goles | Cantidad de goles convertidos por cada equipo en dicha temporada |
# | tiros_porteria | Número de tiros por partido |
# | t_amarillas | Número de tarjetas amarillas recibidas en el torneo |
# | t_rojas | Número de tarjetas rojas recibidas en el torneo |
# | posesion_% | Porcentaje de posesión |
# | pases_% | Porcentaje de pases |
# | duelos_aereos_ganados | Duelos aéreos ganados por partido |
# | valor_gral_eq | Valoración general del equipo |

# %% [markdown]
# <h3>3.2 Carga de DataSet "vec"<h3>

# %%
vec = pd.read_csv("../src/Data/EDA_valuacion_economica_clubes.csv")

# %% [markdown]
# | Nombre columna | Descripción |
# | --------- | --------- |
# | equipo | Club |
# | liga | Liga correspondiente |
# | tamaño_plantilla | Cantidad de jugadores que tiene en su plantilla cada equipo |
# | edad_media_jug | Edad media de los jugadores |
# | valor_eq | Valor de mercado del club |
# | valor_med_merc_jug |  Valor medio de mercado de los jugadores del club |

# %% [markdown]
# ## 4. EXPLORACIÓN INICIAL

# %% [markdown]
# <h3>4.1 Información general del DataSet "edc"<h3>

# %% [markdown]
# Dimensiones del DataFrame:

# %%
edc.shape
# Out:
# (98, 10)

# %% [markdown]
# Mediante head() y tail() observo las primeras y ultimas 5 filas respectivamente para tener un panorama general de los datos:

# %%
edc.head()
# Out:
#                 equipo            liga  goles  tiros_porteria  t_amarillas  \
# 0      Manchester City  Premier League     83            15.8           46
# 1        Bayern Munich      Bundesliga     50            17.1           44
# 2  Paris Saint-Germain         Ligue 1     86            15.0           73
# 3            Barcelona          LaLiga     85            15.3           68
# 4          Real Madrid          LaLiga     67            14.4           57
#
#    t_rojas  posesion_%  pases_%  duelos_aereos_ganados  valor_gral_eq
# 0        2        60.8     89.4                   12.8           7.01
# 1        3        58.1     85.5                   12.9           6.95
# 2        7        60.1     89.5                    9.5           6.88
# 3        2        62.4     89.7                   10.6           6.87
# 4        2        57.7     87.7                   11.8           6.86

# %%
edc.columns
# Out:
# Index(['equipo', 'liga', 'goles', 'tiros_porteria', 't_amarillas', 't_rojas',
#        'posesion_%', 'pases_%', 'duelos_aereos_ganados', 'valor_gral_eq'],
#       dtype='object')

# %%
edc.tail()
# Out:
#               equipo            liga  goles  tiros_porteria  t_amarillas  \
# 93  Sheffield United  Premier League     20             8.5           73
# 94           Crotone         Serie A     45             9.5           85
# 95         Benevento         Serie A     40            11.0           90
# 96             Dijon         Ligue 1     25             9.2           75
# 97        Schalke 04      Bundesliga     25             8.9           70
#
#     t_rojas  posesion_%  pases_%  duelos_aereos_ganados  valor_gral_eq
# 93        3        43.0     76.9                   19.1           6.46
# 94        4        47.2     80.4                   12.7           6.43
# 95        5        44.2     77.7                   13.4           6.43
# 96        5        46.9     80.0                   14.3           6.42
# 97        2        46.2     76.5                   15.6           6.41

# %% [markdown]
# Tipos de datos, ¿existen valores nulos?

# %%
edc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   equipo                 98 non-null     object
#  1   liga                   98 non-null     object
#  2   goles                  98 non-null     int64
#  3   tiros_porteria         98 non-null     float64
#  4   t_amarillas            98 non-null     int64
#  5   t_rojas                98 non-null     int64
#  6   posesion_%             98 non-null     float64
#  7   pases_%                98 non-null     float64
#  8   duelos_aereos_ganados  98 non-null     float64
#  9   valor_gral_eq          98 non-null     float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 7.8+ KB

# %%
edc.dtypes
# Out:
# equipo                    object
# liga                      object
# goles                      int64
# tiros_porteria           float64
# t_amarillas                int64
# t_rojas                    int64
# posesion_%               float64
# pases_%                  float64
# duelos_aereos_ganados    float64
# valor_gral_eq            float64
# dtype: object

# %%
valores_nulos = edc.isnull().sum()/len(edc)*100
print(valores_nulos)
# Out:
# equipo                   0.0
# liga                     0.0
# goles                    0.0
# tiros_porteria           0.0
# t_amarillas              0.0
# t_rojas                  0.0
# posesion_%               0.0
# pases_%                  0.0
# duelos_aereos_ganados    0.0
# valor_gral_eq            0.0
# dtype: float64

# %% [markdown]
# ¿Existen filas duplicadas?

# %%
edc.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Descripción de parámetros estadísticos:

# %%
parametros_estadisticos = edc.describe().round(4)
parametros_estadisticos
# Out:
#          goles  tiros_porteria  t_amarillas  t_rojas  posesion_%  pases_%  \
# count  98.0000         98.0000      98.0000  98.0000     98.0000  98.0000
# mean   51.6837         11.8510      69.7041   3.3367     49.9959  80.4418
# std    15.7373          2.1497      15.1373   2.1488      4.8901   4.6902
# min    20.0000          7.1000      40.0000   0.0000     38.5000  66.5000
# 25%    40.2500         10.3250      60.0000   2.0000     46.2250  78.0250
# 50%    50.0000         11.4500      67.5000   3.0000     49.7500  80.8000
# 75%    61.0000         13.3500      80.0000   4.7500     52.8500  83.4500
# max    90.0000         17.1000     117.0000  10.0000     62.4000  89.7000
#
#        duelos_aereos_ganados  valor_gral_eq
# count                98.0000        98.0000
# mean                 16.0061         6.6461
# std                   3.0790         0.1321
# min                   9.5000         6.4100
# 25%                  14.0250         6.5400
# 50%                  16.1000         6.6300
# 75%                  17.8500         6.7300
# max                  26.8000         7.0100

# %% [markdown]
# Información de las columnas que tienen valores tipo "object":

# %%
edc.describe(include=object)
# edc.describe(include=object).shape
# Out:
#                  equipo            liga
# count                98              98
# unique               98               5
# top     Manchester City  Premier League
# freq                  1              20

# %% [markdown]
# <h3>4.2 Información general del DataSet "vec"<h3>

# %% [markdown]
# Dimensiones del DataFrame:

# %%
vec.shape
# Out:
# (97, 8)

# %% [markdown]
# Panorama general para ver el aspecto de los datos:

# %%
vec.head()
# Out:
#    Unnamed: 0               equipo            liga  tamaño_plantilla  \
# 0           0      Manchester City  Premier League                24
# 1           1  Paris Saint-Germain         Ligue 1                36
# 2           2    Manchester United  Premier League                29
# 3           3              Chelsea  Premier League                27
# 4           4            Liverpool  Premier League                27
#
#    edad_media_jug  valor_eq  valor_med_merc_jug  \
# 0            27.1    970.02               40.42
# 1            26.1    891.18               24.76
# 2            27.9    820.13               28.28
# 3            26.9    802.35               29.72
# 4            27.2    779.85               28.88
#
#    Market Value Of Top 18 Players In Millions(£)
# 0                                         920.70
# 1                                         801.00
# 2                                         742.50
# 3                                         737.10
# 4                                         715.95

# %%
vec.drop("Unnamed: 0", axis=1, inplace=True)
vec
# Out:
#                  equipo            liga  tamaño_plantilla  edad_media_jug  \
# 0       Manchester City  Premier League                24            27.1
# 1   Paris Saint-Germain         Ligue 1                36            26.1
# 2     Manchester United  Premier League                29            27.9
# 3               Chelsea  Premier League                27            26.9
# 4             Liverpool  Premier League                27            27.2
# ..                  ...             ...               ...             ...
# 92             Bordeaux         Ligue 1                30            25.3
# 93              Levante          LaLiga                27            28.1
# 94                 Metz         Ligue 1                29            25.3
# 95     Lokomotiv Moscow    Premier Liga                29            25.0
# 96                Genoa         Serie A                34            27.6
#
#     valor_eq  valor_med_merc_jug  \
# 0     970.02               40.42
# 1     891.18               24.76
# 2     820.13               28.28
# 3     802.35               29.72
# 4     779.85               28.88
# ..       ...                 ...
# 92     89.55                2.99
# 93     89.19                3.30
# 94     89.19                3.08
# 95     87.32                3.01
# 96     86.94                2.56
#
#     Market Value Of Top 18 Players In Millions(£)
# 0                                          920.70
# 1                                          801.00
# 2                                          742.50
# 3                                          737.10
# 4                                          715.95
# ..                                            ...
# 92                                          78.75
# 93                                          82.35
# 94                                          79.74
# 95                                          77.85
# 96                                          72.27
#
# [97 rows x 7 columns]

# %%
vec.tail()
# Out:
#               equipo          liga  tamaño_plantilla  edad_media_jug  \
# 92          Bordeaux       Ligue 1                30            25.3
# 93           Levante        LaLiga                27            28.1
# 94              Metz       Ligue 1                29            25.3
# 95  Lokomotiv Moscow  Premier Liga                29            25.0
# 96             Genoa       Serie A                34            27.6
#
#     valor_eq  valor_med_merc_jug  \
# 92     89.55                2.99
# 93     89.19                3.30
# 94     89.19                3.08
# 95     87.32                3.01
# 96     86.94                2.56
#
#     Market Value Of Top 18 Players In Millions(£)
# 92                                          78.75
# 93                                          82.35
# 94                                          79.74
# 95                                          77.85
# 96                                          72.27

# %% [markdown]
# Tipos de datos, ¿existen valores nulos?

# %%
vec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 7 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   equipo                                         97 non-null     object
#  1   liga                                           97 non-null     object
#  2   tamaño_plantilla                               97 non-null     int64
#  3   edad_media_jug                                 97 non-null     float64
#  4   valor_eq                                       97 non-null     float64
#  5   valor_med_merc_jug                             97 non-null     float64
#  6   Market Value Of Top 18 Players In Millions(£)  97 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.4+ KB

# %%
vec.dtypes
# Out:
# equipo                                            object
# liga                                              object
# tamaño_plantilla                                   int64
# edad_media_jug                                   float64
# valor_eq                                         float64
# valor_med_merc_jug                               float64
# Market Value Of Top 18 Players In Millions(£)    float64
# dtype: object

# %%
valores_nulos = vec.isnull().sum()/len(vec)*100
print(valores_nulos)
# Out:
# equipo                                           0.0
# liga                                             0.0
# tamaño_plantilla                                 0.0
# edad_media_jug                                   0.0
# valor_eq                                         0.0
# valor_med_merc_jug                               0.0
# Market Value Of Top 18 Players In Millions(£)    0.0
# dtype: float64

# %% [markdown]
# ¿Existen filas duplicadas?

# %%
vec.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Descripción de parámetros estadísticos:

# %%
vec.describe().round(4)
# Out:
#        tamaño_plantilla  edad_media_jug  valor_eq  valor_med_merc_jug  \
# count           97.0000         97.0000   97.0000             97.0000
# mean            27.7010         26.3268  269.0333              9.8813
# std              2.8474          1.4194  206.4135              7.7824
# min             22.0000         23.0000   86.9400              2.5600
# 25%             26.0000         25.5000  119.7000              4.2500
# 50%             27.0000         26.1000  182.7500              7.1100
# 75%             29.0000         27.4000  345.6900             13.2800
# max             36.0000         30.1000  970.0200             40.4200
#
#        Market Value Of Top 18 Players In Millions(£)
# count                                        97.0000
# mean                                        248.3166
# std                                         191.2185
# min                                          72.2700
# 25%                                         112.0500
# 50%                                         175.9500
# 75%                                         324.4500
# max                                         920.7000

# %% [markdown]
# La media y la mediana tienen casi los mismos valores en cada una de las variables, lo cual indica que la distribución de los datos es normal.

# %% [markdown]
# En todos los casos se observa que la desviación estándar es ligeramente menor al rango intercuartil. Esto indica que los datos están mas concentrados y que hay pocos valores atípicos.

# %% [markdown]
# Información de las columnas que tienen valores tipo "object":

# %%
vec.describe(include=object)
# Out:
#                  equipo            liga
# count                97              97
# unique               97              15
# top     Manchester City  Premier League
# freq                  1              20

# %% [markdown]
# En este primer análisis lo que se observa a simple vista es que el DataSet "edc" contiene una dimensión de 98 filas y 10 columnas, mientras que el DataSet "vec" tiene dimensiones muy similares, 97 filas y 8 columnas.
#
# De las diez columnas del DataSet "edc", dos son categóricas (de tipo “object”) y las ocho restantes numéricas (cinco variables de tipo “float64” y las otras tres de tipo “int64”). En el caso del DataSet "vec" nos encontramos con cuatro variables que son de tipo "float64", un "int64" y dos de tipo "object".
#
# Se puede observar que no existen valores nulos en ninguno de los dos DataSet, tampoco filas duplicadas. Si algunos valores outliers que se detectan y tratan a continuación.
#
# De acuerdo a los parámetros estadísticos de las variables tipo object, cada registro de la columnas “equipo” cuenta con un valor único, y en el caso de la columna “liga” que tiene 5 valores únicos de los 98 registros, la liga que aparece con mayor frecuencia (20 veces) es la Premier League.

# %% [markdown]
# ## 5. LIMPIEZA DE LOS DATASETS

# %% [markdown]
# Renombro las columnas:

# %%
edc.rename(columns={'Team': 'equipo', 'Tournament': 'liga','Goals': 'goles', 'Shots pg': 'tiros_porteria',
                    'yellow_cards': 't_amarillas', 'red_cards': 't_rojas', 'Possession%': 'posesion_%',
                      'Pass%': 'pases_%', 'AerialsWon': 'duelos_aereos_ganados', 'Rating': 'valor_gral_eq'}
                      , inplace=True)

# %%
vec.rename(columns={'Club Name':'equipo', 'Competition Name':'liga', 
                    'Squad Size':'tamaño_plantilla','Average Age Of Players':'edad_media_jug', 
                    'Market Value Of Club In Millions(£)':'valor_monet_eq',
                    'Average Market Value Of Players In Millions(£)':'valor_med_merc_jug',
                    'Market Value Of Top 18 Players In Millions(£)':'Market Value Of Top 18 Players In Millions(£)'}
                    , inplace=True)

# %% [markdown]
# Elimino columna:

# %%
vec.drop(columns=["Market Value Of Top 18 Players In Millions(£)"])
# Out:
#                  equipo            liga  tamaño_plantilla  edad_media_jug  \
# 0       Manchester City  Premier League                24            27.1
# 1   Paris Saint-Germain         Ligue 1                36            26.1
# 2     Manchester United  Premier League                29            27.9
# 3               Chelsea  Premier League                27            26.9
# 4             Liverpool  Premier League                27            27.2
# ..                  ...             ...               ...             ...
# 92             Bordeaux         Ligue 1                30            25.3
# 93              Levante          LaLiga                27            28.1
# 94                 Metz         Ligue 1                29            25.3
# 95     Lokomotiv Moscow    Premier Liga                29            25.0
# 96                Genoa         Serie A                34            27.6
#
#     valor_eq  valor_med_merc_jug
# 0     970.02               40.42
# 1     891.18               24.76
# 2     820.13               28.28
# 3     802.35               29.72
# 4     779.85               28.88
# ..       ...                 ...
# 92     89.55                2.99
# 93     89.19                3.30
# 94     89.19                3.08
# 95     87.32                3.01
# 96     86.94                2.56
#
# [97 rows x 6 columns]

# %%
from scipy.stats import probplot

# Generar datos que se sospecha que siguen una distribución normal

# Crear un gráfico Q-Q
probplot(edc['goles'], dist="norm", plot=plt)
plt.title("Q-Q Plot")
plt.xlabel("Cuantiles teóricos")
plt.ylabel("Cuantiles observados")
plt.show()

# %% [markdown]
# ¿Existen outliers en el DataFrame? ¿Qué variables presentan outliers? ¿Cómo es la dispersion de los datos?

# %%
from scipy.stats import shapiro

prueba_normalidad = edc["goles","tiros_porteria","posesion_%"].values

# Realizar la prueba de Shapiro-Wilk
statistic, p_value = shapiro(prueba_normalidad)

print("Estadístico de Shapiro-Wilk:", statistic)
print("Valor p:", p_value)

alpha = 0.05
if p_value < alpha:
    print("""Rechazamos la hipótesis nula.
          La distribución de las estadísticas 
          de goles no sigue una distribución normal.""")
else:
    print("No podemos rechazar la hipótesis nula.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\feder\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('goles', 'tiros_porteria', 'posesion_%')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[318], line 3
#       1 from scipy.stats import shapiro
# ----> 3 prueba_normalidad = edc["goles","tiros_porteria","posesion_%"].values
#       5 # Realizar la prueba de Shapiro-Wilk
#       6 statistic, p_value = shapiro(prueba_normalidad)
#
# File c:\Users\feder\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\feder\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: ('goles', 'tiros_porteria', 'posesion_%')

# %%
plt.figure(figsize=(10,5))
sns.distplot(edc['goles'], hist = False)
# Out:
# C:\Users\feder\AppData\Local\Temp\ipykernel_5276\1120718528.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edc['goles'], hist = False)
# <Axes: xlabel='goles', ylabel='Density'>

# %%
sns.histplot(edc["goles"], kde=True)
plt.title("Histograma")
# Out:
# Text(0.5, 1.0, 'Histograma')

# %%
np.random.seed(14)
edc = np.random.normal(loc=20, scale=5, size=100)

# Intervalo de confianza para la media (95%):
intervalo_confianza = stats.norm.interval(0.95, loc=np.mean(edc), scale=stats.sem(edc))

# Gráfico KDE de los datos
sns.kdeplot(edc, shade=True, color='blue', label='Densidad de probabilidad')

media = np.mean(edc)
plt.axvline(media, color='yellow', linestyle='dashed', linewidth=2, label='Media de la muestra')
plt.axvline(intervalo_confianza[0], color='blue', linestyle='dashed', linewidth=2, label='Intervalo de confianza')
plt.axvline(intervalo_confianza[1], color='blue', linestyle='dashed', linewidth=2)

plt.xlabel('Valores')
plt.ylabel('Densidad de probabilidad')
plt.title('Gráfico KDE e Intervalo de Confianza')
plt.legend()

plt.show()
# Out:
# C:\Users\feder\AppData\Local\Temp\ipykernel_5276\2681350480.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(edc, shade=True, color='blue', label='Densidad de probabilidad')

# %%
edc = np.random.normal(0, 1, 200)
sns.histplot(edc, bins = 10)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Como se observa en los graficos anteriores, la distribución tiende a ser normal y la gráfica leptocúrtica. Existen pocos valores Outliers, los cuales se tratan a continuación.

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=edc)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data=edc)

# Calculo del rango intercuartílico
Q1 = edc['goles'].quantile(0.25)
Q3 = edc['goles'].quantile(0.75)
IQR = Q3 - Q1

# Calculo de los límites inferior y superior
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Identificación de outliers
outliers_goles = edc[(edc['goles'] < limite_inferior) | (edc['goles'] > limite_superior)]
outliers_goles
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[224], line 5
#       2 sns.boxplot(data=edc)
#       4 # Calculo del rango intercuartílico
# ----> 5 Q1 = edc['goles'].quantile(0.25)
#       6 Q3 = edc['goles'].quantile(0.75)
#       7 IQR = Q3 - Q1
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
'''plt.figure(figsize=(10,4))
sns.boxplot(data=edc)

# Calculo del rango intercuartílico
Q1 = edc['t_amarillas'].quantile(0.25)
Q3 = edc['t_amarillas'].quantile(0.75)
IQR = Q3 - Q1

# Calculo de los límites inferior y superior
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers_t_amarillas = edc[(edc['t_amarillas'] < limite_inferior) | (edc['t_amarillas'] > limite_superior)]
outliers_t_amarillas

En esta variable al único valor outlier encontrado también lo reemplazo por la moda.
moda_t_amarillas = edc["t_amarillas"].mode()
moda_t_amarillas
edc.at[89,"t_amarillas"] = moda_t_amarillas'''
# Out:
# 'plt.figure(figsize=(10,4))\nsns.boxplot(data=edc)\n\n# Calculo del rango intercuartílico\nQ1 = edc[\'t_amarillas\'].quantile(0.25)\nQ3 = edc[\'t_amarillas\'].quantile(0.75)\nIQR = Q3 - Q1\n\n# Calculo de los límites inferior y superior\nlimite_inferior = Q1 - 1.5 * IQR\nlimite_superior = Q3 + 1.5 * IQR\n\noutliers_t_amarillas = edc[(edc[\'t_amarillas\'] < limite_inferior) | (edc[\'t_amarillas\'] > limite_superior)]\noutliers_t_amarillas\n\nEn esta variable al único valor outlier encontrado también lo reemplazo por la moda.\nmoda_t_amarillas = edc["t_amarillas"].mode()\nmoda_t_amarillas\nedc.at[89,"t_amarillas"] = moda_t_amarillas'

# %%
'''
Respecto a los outliers de la variable tarjetas rojas no se realiza ningún tipo de modificación. 
En comparación a las tarjetas amarillas se reciben menos por temporada, sumado a que es muy corta la
brecha entre máximo y mínimo de tarjetas recibidas, lo cual hace que haya menor variación entre 
las observaciones.

#plt.figure(figsize=(10,4))
#sns.boxplot(data=edc)

# Calculo del rango intercuartílico
Q1 = edc['t_rojas'].quantile(0.25)
Q3 = edc['t_rojas'].quantile(0.75)
IQR = Q3 - Q1

# Calculo de los límites inferior y superior
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers_t_rojas = edc[(edc['t_rojas'] < limite_inferior) | (edc['t_rojas'] > limite_superior)]
outliers_t_rojas'''
# Out:
# "\nRespecto a los outliers de la variable tarjetas rojas no se realiza ningún tipo de modificación. \nEn comparación a las tarjetas amarillas se reciben menos por temporada, sumado a que es muy corta la\nbrecha entre máximo y mínimo de tarjetas recibidas, lo cual hace que haya menor variación entre \nlas observaciones.\n\n#plt.figure(figsize=(10,4))\n#sns.boxplot(data=edc)\n\n# Calculo del rango intercuartílico\nQ1 = edc['t_rojas'].quantile(0.25)\nQ3 = edc['t_rojas'].quantile(0.75)\nIQR = Q3 - Q1\n\n# Calculo de los límites inferior y superior\nlimite_inferior = Q1 - 1.5 * IQR\nlimite_superior = Q3 + 1.5 * IQR\n\noutliers_t_rojas = edc[(edc['t_rojas'] < limite_inferior) | (edc['t_rojas'] > limite_superior)]\noutliers_t_rojas"

# %% [markdown]
# Se guardan los DataFrames:

# %%
'''edc.to_csv("../src/Data/EDA_estadisticas_deportivas_clubes.csv")'''
# Out:
# 'edc.to_csv("../src/Data/EDA_estadisticas_deportivas_clubes.csv")'

# %%
'''vec.to_csv("../src/Data/EDA_valuacion_economica_clubes.csv")'''
# Out:
# 'vec.to_csv("../src/Data/EDA_valuacion_economica_clubes.csv")'

# %% [markdown]
# ## 6. ANÁLISIS DE DATOS

# %% [markdown]
# <h3>6.1 Univariante<h3>

# %% [markdown]
# Mediante un Histograma se puede ver si las variables/columnas tienden a una distribución normal:

# %%
azul = "#008B8B"
edc.hist(figsize=(20,15), grid=False, color=azul);

# %%
azul = "#008B8B"
vec.hist(figsize=(20,15), grid=False, color=azul);

# %% [markdown]
# Se denota cierta tendencia a la normalidad en cada una de las variables, con una leve asimetría positiva en todas las graficas excepto la correspondiente a la columna de pases_% que tiene asimetría negativa.

# %% [markdown]
# <h3>6.2 Bivariante<h3>

# %% [markdown]
# **Hipótesis 2:**

# %% [markdown]
# **Ho:** No existe una relación directamente proporcional entre cantidad promedio de tiros a porteria por temporada con la cantidad de goles marcados en el torneo por cada equipo.
#
# **H1:** Los equipos que en promedio patearon mayor cantidad de veces a porteria por partido en dicha temporada marcaron mayor cantidad de goles en el torneo.

# %%
'''edc[["equipo","tiros_porteria","goles"]]'''
# Out:
# 'edc[["equipo","tiros_porteria","goles"]]'

# %%
equipo = edc["equipo"]
tiros_porteria = edc["tiros_porteria"]
goles = edc["goles"]

plt.figure(figsize=(8, 6))
plt.scatter(tiros_porteria, goles, c='b', marker='o', label='Equipos')

plt.xlabel('Promedio de tiros a portería por partido')
plt.ylabel('Cantidad total de goles')

plt.title('Relación entre tiros a portería y goles marcados')

for i, equipo in enumerate(equipo):
    plt.annotate(equipo, (tiros_porteria[i], goles[i]), textcoords="offset points", xytext=(0,5), ha='center')

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# **Hipótesis 3:**

# %% [markdown]
# **Ho:** Los equipos que tuvieron mayor cantidad de tiempo el balón por partido en dicha temporada no necesariamente marcaron mayor cantidad de goles en el torneo.
#
# **H1:** Los equipos con mayor posesión del balón por partido en dicha temporada marcaron mayor cantidad de goles en el torneo.

# %%
edc[["equipo","posesion_%","goles"]]
# Out:
#                  equipo  posesion_%  goles
# 0       Manchester City        60.8     83
# 1         Bayern Munich        58.1     50
# 2   Paris Saint-Germain        60.1     86
# 3             Barcelona        62.4     85
# 4           Real Madrid        57.7     67
# ..                  ...         ...    ...
# 93     Sheffield United        43.0     20
# 94              Crotone        47.2     45
# 95            Benevento        44.2     40
# 96                Dijon        46.9     25
# 97           Schalke 04        46.2     25
#
# [98 rows x 3 columns]

# %%
sns.jointplot(data=edc, x='posesion_%', y='goles', kind='hex');

# %% [markdown]
# Se corrobora de manera muy clara con este gráfico la relación entre estas dos variables. La mayor cantidad de datos se encuentran concentrados en la intersección cercana a 45% de posesion y 45 goles.

# %% [markdown]
# **Hipótesis 4:**

# %% [markdown]
# **Ho:** Los clubes que obtuvieron mayor cantidad de tarjetas amarillas y rojas a lo largo de un temporada no necesariamente están peor valorados deportivamente.
#
# **H1:** Los clubes con mejor rating o valoración general han recibido menor cantidad de tarjetas amarillas y tarjetas rojas a lo largo de una temporada.

# %%
edc['suma_tarjetas'] = edc['t_amarillas'] + edc['t_rojas']

edc[["equipo","t_amarillas","t_rojas","suma_tarjetas","valor_gral_eq"]]
# Out:
#                  equipo  t_amarillas  t_rojas  suma_tarjetas  valor_gral_eq
# 0       Manchester City           46        2             48           7.01
# 1         Bayern Munich           44        3             47           6.95
# 2   Paris Saint-Germain           73        7             80           6.88
# 3             Barcelona           68        2             70           6.87
# 4           Real Madrid           57        2             59           6.86
# ..                  ...          ...      ...            ...            ...
# 93     Sheffield United           73        3             76           6.46
# 94              Crotone           85        4             89           6.43
# 95            Benevento           90        5             95           6.43
# 96                Dijon           75        5             80           6.42
# 97           Schalke 04           70        2             72           6.41
#
# [98 rows x 5 columns]

# %%
sns.scatterplot(data=edc, x='suma_tarjetas', y='valor_gral_eq',hue='liga');
sns.regplot(x='suma_tarjetas', y='valor_gral_eq', data=edc, scatter=False, color='blue');

for group in edc['liga'].unique():
    sns.regplot(x='suma_tarjetas', y='valor_gral_eq', data=edc[edc['liga'] == group], scatter=False, label=f'Reg: {group}')

# %% [markdown]
# El grafico muestra, que excepto la liga francesa, el resto mantiene un comportamiento negativamente proporcional entre ambas variables.

# %% [markdown]
# **Hipótesis 5:**

# %% [markdown]
# **Ho:** No existe una relación directa entre el valor de mercado promedio de los jugadores de cada equipo y la valoración económica de las ligas.

# %% [markdown]
# **H1:** El valor de mercado de los clubes es mayor a medida que aumenta el promedio del valor de mercado de sus jugadores.

# %%
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="valor_eq", y=edc["liga"], data=vec,
            label="valoracion equipo", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="valor_med_merc_jug", y=edc["liga"], data=vec,
            label="valor de mercado promedio de los jugadores", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
sns.despine(left=True, bottom=True)

# %% [markdown]
# Como se puede observar en esta gráfica, la Premier League tiene un valor de mercado promedio de los jugadores por encima del resto de las ligas y a su vez cuenta con los quipos con mayor valor de mercado, con lo cual podemos afirmar la hipótesis alternativa.

# %% [markdown]
# <h3>6.3 Multivariante<h3>

# %% [markdown]
# Genero un DataFrame numérico para ver la correlación entre las variables y lo visualizo mediante heatmap:

# %%
dataframe_numerico = edc.iloc[:,2:]
dataframe_numerico
# Out:
#     goles  tiros_porteria  t_amarillas  t_rojas  posesion_%  pases_%  \
# 0      83            15.8           46        2        60.8     89.4
# 1      50            17.1           44        3        58.1     85.5
# 2      86            15.0           73        7        60.1     89.5
# 3      85            15.3           68        2        62.4     89.7
# 4      67            14.4           57        2        57.7     87.7
# ..    ...             ...          ...      ...         ...      ...
# 93     20             8.5           73        3        43.0     76.9
# 94     45             9.5           85        4        47.2     80.4
# 95     40            11.0           90        5        44.2     77.7
# 96     25             9.2           75        5        46.9     80.0
# 97     25             8.9           70        2        46.2     76.5
#
#     duelos_aereos_ganados  valor_gral_eq  suma_tarjetas
# 0                    12.8           7.01             48
# 1                    12.9           6.95             47
# 2                     9.5           6.88             80
# 3                    10.6           6.87             70
# 4                    11.8           6.86             59
# ..                    ...            ...            ...
# 93                   19.1           6.46             76
# 94                   12.7           6.43             89
# 95                   13.4           6.43             95
# 96                   14.3           6.42             80
# 97                   15.6           6.41             72
#
# [98 rows x 9 columns]

# %%
dataframe_numerico.corr()
# Out:
#                           goles  tiros_porteria  t_amarillas   t_rojas  \
# goles                  1.000000        0.788670    -0.143165  0.003792
# tiros_porteria         0.788670        1.000000    -0.369343 -0.105080
# t_amarillas           -0.143165       -0.369343     1.000000  0.368847
# t_rojas                0.003792       -0.105080     0.368847  1.000000
# posesion_%             0.696951        0.759153    -0.164302 -0.083360
# pases_%                0.690846        0.684035    -0.184238 -0.043761
# duelos_aereos_ganados -0.485505       -0.382147     0.060116 -0.031791
# valor_gral_eq          0.816699        0.851265    -0.417049 -0.162358
# suma_tarjetas         -0.134478       -0.362304     0.992231  0.481616
#
#                        posesion_%   pases_%  duelos_aereos_ganados  \
# goles                    0.696951  0.690846              -0.485505
# tiros_porteria           0.759153  0.684035              -0.382147
# t_amarillas             -0.164302 -0.184238               0.060116
# t_rojas                 -0.083360 -0.043761              -0.031791
# posesion_%               1.000000  0.851458              -0.543970
# pases_%                  0.851458  1.000000              -0.764788
# duelos_aereos_ganados   -0.543970 -0.764788               1.000000
# valor_gral_eq            0.734978  0.668573              -0.327225
# suma_tarjetas           -0.166072 -0.179568               0.052426
#
#                        valor_gral_eq  suma_tarjetas
# goles                       0.816699      -0.134478
# tiros_porteria              0.851265      -0.362304
# t_amarillas                -0.417049       0.992231
# t_rojas                    -0.162358       0.481616
# posesion_%                  0.734978      -0.166072
# pases_%                     0.668573      -0.179568
# duelos_aereos_ganados      -0.327225       0.052426
# valor_gral_eq               1.000000      -0.414951
# suma_tarjetas              -0.414951       1.000000

# %%
plt.figure(figsize=(12,9))
sns.heatmap(dataframe_numerico.corr(),
           vmin=-1,vmax=1,annot=True,linewidths=0.5,cmap="Blues");

# %% [markdown]
# Como se observa en el grafico anterior existe un mayor grado de correlación entre ciertas variables.
# Se podría a priori decir que, aunque no sea la causa, sí existe un comportamiento similar entre los datos
# de "goles" y "tiros_porteria" (ambos 0.85) con la variable "valor_gral_eq"; y en menor medida, "posesion_%" (0.73) y "pases_%" (0.67) con la misma variable "valor_gral_eq".
# Las restantes columnas ("t_amarillas", "t_rojas" y "duelos_aereos_ganados") tienen un grado de correlacion  muy bajo.

# %% [markdown]
# Corroboro si los equipos del DataSet "edc" coinciden con los equipos del DataSet "vec", para realizar el MERGE por la columna "equipo".

# %%
columnas_equipo = edc['equipo'].isin(vec['equipo'])
print(columnas_equipo)

# la máscara booleana me muestra con True aquellos que sí estan en ambas columnas.
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 93     True
# 94    False
# 95    False
# 96    False
# 97    False
# Name: equipo, Length: 98, dtype: bool

# %% [markdown]
# ¿Cuántos equipos coinciden?

# %%
'''
El 67% de los equipos están en ambas columnas, considero una muestra representativa para realizar un merge.
'''

conteo = columnas_equipo.value_counts()/len(columnas_equipo)*100.
print(conteo)
# Out:
# equipo
# True     67.346939
# False    32.653061
# Name: count, dtype: float64

# %%
merge_edc_vec = pd.merge(edc, vec, left_on='equipo', right_on='equipo', how='inner')
merge_edc_vec
# Out:
#                  equipo          liga_x  goles  tiros_porteria  t_amarillas  \
# 0       Manchester City  Premier League     83            15.8           46
# 1         Bayern Munich      Bundesliga     50            17.1           44
# 2   Paris Saint-Germain         Ligue 1     86            15.0           73
# 3             Barcelona          LaLiga     85            15.3           68
# 4           Real Madrid          LaLiga     67            14.4           57
# ..                  ...             ...    ...             ...          ...
# 61                Genoa         Serie A     47             9.0           85
# 62           Fiorentina         Serie A     47             9.8           86
# 63              Levante          LaLiga     46            10.1           70
# 64               Getafe          LaLiga     28             9.5          117
# 65     Sheffield United  Premier League     20             8.5           73
#
#     t_rojas  posesion_%  pases_%  duelos_aereos_ganados  valor_gral_eq  \
# 0         2        60.8     89.4                   12.8           7.01
# 1         3        58.1     85.5                   12.9           6.95
# 2         7        60.1     89.5                    9.5           6.88
# 3         2        62.4     89.7                   10.6           6.87
# 4         2        57.7     87.7                   11.8           6.86
# ..      ...         ...      ...                    ...            ...
# 61        2        46.1     79.7                   13.7           6.54
# 62        5        46.8     81.0                   14.2           6.52
# 63        1        51.5     80.1                   12.2           6.50
# 64        7        44.4     66.5                   22.8           6.49
# 65        3        43.0     76.9                   19.1           6.46
#
#     suma_tarjetas                  liga_y  tamaño_plantilla  edad_media_jug  \
# 0              48          Premier League                24            27.1
# 1              47  BundesligBayern Munich                26            26.1
# 2              80                 Ligue 1                36            26.1
# 3              70                  LaLiga                30            25.9
# 4              59                  LaLiga                27            27.3
# ..            ...                     ...               ...             ...
# 61             87                 Serie A                34            27.6
# 62             91                 Serie A                26            27.0
# 63             71                  LaLiga                27            28.1
# 64            124                  LaLiga                25            27.3
# 65             76            Championship                28            27.9
#
#     valor_eq  valor_med_merc_jug  \
# 0     970.02               40.42
# 1     756.45               29.09
# 2     891.18               24.76
# 3     592.20               19.74
# 4     680.40               25.20
# ..       ...                 ...
# 61     86.94                2.56
# 62    228.42                8.79
# 63     89.19                3.30
# 64    141.30                5.65
# 65    112.05                4.00
#
#     Market Value Of Top 18 Players In Millions(£)
# 0                                          920.70
# 1                                          726.21
# 2                                          801.00
# 3                                          535.50
# 4                                          610.20
# ..                                            ...
# 61                                          72.27
# 62                                         214.02
# 63                                          82.35
# 64                                         135.45
# 65                                         102.51
#
# [66 rows x 17 columns]

# %%
general_data = merge_edc_vec.drop(columns=["equipo","liga_x","liga_y","Market Value Of Top 18 Players In Millions(£)"])
general_data
# Out:
#     goles  tiros_porteria  t_amarillas  t_rojas  posesion_%  pases_%  \
# 0      83            15.8           46        2        60.8     89.4
# 1      50            17.1           44        3        58.1     85.5
# 2      86            15.0           73        7        60.1     89.5
# 3      85            15.3           68        2        62.4     89.7
# 4      67            14.4           57        2        57.7     87.7
# ..    ...             ...          ...      ...         ...      ...
# 61     47             9.0           85        2        46.1     79.7
# 62     47             9.8           86        5        46.8     81.0
# 63     46            10.1           70        1        51.5     80.1
# 64     28             9.5          117        7        44.4     66.5
# 65     20             8.5           73        3        43.0     76.9
#
#     duelos_aereos_ganados  valor_gral_eq  suma_tarjetas  tamaño_plantilla  \
# 0                    12.8           7.01             48                24
# 1                    12.9           6.95             47                26
# 2                     9.5           6.88             80                36
# 3                    10.6           6.87             70                30
# 4                    11.8           6.86             59                27
# ..                    ...            ...            ...               ...
# 61                   13.7           6.54             87                34
# 62                   14.2           6.52             91                26
# 63                   12.2           6.50             71                27
# 64                   22.8           6.49            124                25
# 65                   19.1           6.46             76                28
#
#     edad_media_jug  valor_eq  valor_med_merc_jug
# 0             27.1    970.02               40.42
# 1             26.1    756.45               29.09
# 2             26.1    891.18               24.76
# 3             25.9    592.20               19.74
# 4             27.3    680.40               25.20
# ..             ...       ...                 ...
# 61            27.6     86.94                2.56
# 62            27.0    228.42                8.79
# 63            28.1     89.19                3.30
# 64            27.3    141.30                5.65
# 65            27.9    112.05                4.00
#
# [66 rows x 13 columns]

# %%
# corroboro que en este nuevo DataFrame generado a partir del merge realizado no se hayan generado Nulos.

general_data.isnull().sum()
# Out:
# goles                    0
# tiros_porteria           0
# t_amarillas              0
# t_rojas                  0
# posesion_%               0
# pases_%                  0
# duelos_aereos_ganados    0
# valor_gral_eq            0
# suma_tarjetas            0
# tamaño_plantilla         0
# edad_media_jug           0
# valor_eq                 0
# valor_med_merc_jug       0
# dtype: int64

# %%
general_data.corr()
# Out:
#                           goles  tiros_porteria  t_amarillas   t_rojas  \
# goles                  1.000000        0.758084    -0.123963  0.038519
# tiros_porteria         0.758084        1.000000    -0.371960 -0.019115
# t_amarillas           -0.123963       -0.371960     1.000000  0.360572
# t_rojas                0.038519       -0.019115     0.360572  1.000000
# posesion_%             0.654856        0.722186    -0.198864 -0.014186
# pases_%                0.679592        0.676294    -0.235901  0.057469
# duelos_aereos_ganados -0.521636       -0.466143     0.137819 -0.122293
# valor_gral_eq          0.771551        0.820303    -0.430396 -0.127058
# suma_tarjetas         -0.112056       -0.353982     0.992416  0.472496
# tamaño_plantilla       0.166518        0.206690     0.044452  0.150064
# edad_media_jug        -0.080303       -0.182928     0.097312 -0.130184
# valor_eq               0.637584        0.657917    -0.368966 -0.116475
# valor_med_merc_jug     0.591209        0.611623    -0.364077 -0.153952
#
#                        posesion_%   pases_%  duelos_aereos_ganados  \
# goles                    0.654856  0.679592              -0.521636
# tiros_porteria           0.722186  0.676294              -0.466143
# t_amarillas             -0.198864 -0.235901               0.137819
# t_rojas                 -0.014186  0.057469              -0.122293
# posesion_%               1.000000  0.829001              -0.619714
# pases_%                  0.829001  1.000000              -0.819910
# duelos_aereos_ganados   -0.619714 -0.819910               1.000000
# valor_gral_eq            0.686382  0.641960              -0.368546
# suma_tarjetas           -0.189775 -0.215328               0.114107
# tamaño_plantilla         0.187408  0.216084              -0.256483
# edad_media_jug          -0.257566 -0.125324               0.163305
# valor_eq                 0.684367  0.656817              -0.433942
# valor_med_merc_jug       0.632968  0.612325              -0.381342
#
#                        valor_gral_eq  suma_tarjetas  tamaño_plantilla  \
# goles                       0.771551      -0.112056          0.166518
# tiros_porteria              0.820303      -0.353982          0.206690
# t_amarillas                -0.430396       0.992416          0.044452
# t_rojas                    -0.127058       0.472496          0.150064
# posesion_%                  0.686382      -0.189775          0.187408
# pases_%                     0.641960      -0.215328          0.216084
# duelos_aereos_ganados      -0.368546       0.114107         -0.256483
# valor_gral_eq               1.000000      -0.423424         -0.009411
# suma_tarjetas              -0.423424       1.000000          0.061780
# tamaño_plantilla           -0.009411       0.061780          1.000000
# edad_media_jug             -0.078157       0.074793         -0.345574
# valor_eq                    0.842047      -0.363984         -0.034016
# valor_med_merc_jug          0.829701      -0.364304         -0.195935
#
#                        edad_media_jug  valor_eq  valor_med_merc_jug
# goles                       -0.080303  0.637584            0.591209
# tiros_porteria              -0.182928  0.657917            0.611623
# t_amarillas                  0.097312 -0.368966           -0.364077
# t_rojas                     -0.130184 -0.116475           -0.153952
# posesion_%                  -0.257566  0.684367            0.632968
# pases_%                     -0.125324  0.656817            0.612325
# duelos_aereos_ganados        0.163305 -0.433942           -0.381342
# valor_gral_eq               -0.078157  0.842047            0.829701
# suma_tarjetas                0.074793 -0.363984           -0.364304
# tamaño_plantilla            -0.345574 -0.034016           -0.195935
# edad_media_jug               1.000000  0.053586            0.102828
# valor_eq                     0.053586  1.000000            0.979720
# valor_med_merc_jug           0.102828  0.979720            1.000000

# %%
plt.figure(figsize=(12,9))
sns.heatmap(general_data.corr(),
           vmin=-1,vmax=1,annot=True,linewidths=0.5,cmap="Blues");

# %%
corr_hipotesis = general_data.corr(method='pearson')

# Mostrar matriz de correlación
print(corr_hipotesis)
# Out:
#                           goles  tiros_porteria  t_amarillas   t_rojas  \
# goles                  1.000000        0.758084    -0.123963  0.038519
# tiros_porteria         0.758084        1.000000    -0.371960 -0.019115
# t_amarillas           -0.123963       -0.371960     1.000000  0.360572
# t_rojas                0.038519       -0.019115     0.360572  1.000000
# posesion_%             0.654856        0.722186    -0.198864 -0.014186
# pases_%                0.679592        0.676294    -0.235901  0.057469
# duelos_aereos_ganados -0.521636       -0.466143     0.137819 -0.122293
# valor_gral_eq          0.771551        0.820303    -0.430396 -0.127058
# suma_tarjetas         -0.112056       -0.353982     0.992416  0.472496
# tamaño_plantilla       0.166518        0.206690     0.044452  0.150064
# edad_media_jug        -0.080303       -0.182928     0.097312 -0.130184
# valor_eq               0.637584        0.657917    -0.368966 -0.116475
# valor_med_merc_jug     0.591209        0.611623    -0.364077 -0.153952
#
#                        posesion_%   pases_%  duelos_aereos_ganados  \
# goles                    0.654856  0.679592              -0.521636
# tiros_porteria           0.722186  0.676294              -0.466143
# t_amarillas             -0.198864 -0.235901               0.137819
# t_rojas                 -0.014186  0.057469              -0.122293
# posesion_%               1.000000  0.829001              -0.619714
# pases_%                  0.829001  1.000000              -0.819910
# duelos_aereos_ganados   -0.619714 -0.819910               1.000000
# valor_gral_eq            0.686382  0.641960              -0.368546
# suma_tarjetas           -0.189775 -0.215328               0.114107
# tamaño_plantilla         0.187408  0.216084              -0.256483
# edad_media_jug          -0.257566 -0.125324               0.163305
# valor_eq                 0.684367  0.656817              -0.433942
# valor_med_merc_jug       0.632968  0.612325              -0.381342
#
#                        valor_gral_eq  suma_tarjetas  tamaño_plantilla  \
# goles                       0.771551      -0.112056          0.166518
# tiros_porteria              0.820303      -0.353982          0.206690
# t_amarillas                -0.430396       0.992416          0.044452
# t_rojas                    -0.127058       0.472496          0.150064
# posesion_%                  0.686382      -0.189775          0.187408
# pases_%                     0.641960      -0.215328          0.216084
# duelos_aereos_ganados      -0.368546       0.114107         -0.256483
# valor_gral_eq               1.000000      -0.423424         -0.009411
# suma_tarjetas              -0.423424       1.000000          0.061780
# tamaño_plantilla           -0.009411       0.061780          1.000000
# edad_media_jug             -0.078157       0.074793         -0.345574
# valor_eq                    0.842047      -0.363984         -0.034016
# valor_med_merc_jug          0.829701      -0.364304         -0.195935
#
#                        edad_media_jug  valor_eq  valor_med_merc_jug
# goles                       -0.080303  0.637584            0.591209
# tiros_porteria              -0.182928  0.657917            0.611623
# t_amarillas                  0.097312 -0.368966           -0.364077
# t_rojas                     -0.130184 -0.116475           -0.153952
# posesion_%                  -0.257566  0.684367            0.632968
# pases_%                     -0.125324  0.656817            0.612325
# duelos_aereos_ganados        0.163305 -0.433942           -0.381342
# valor_gral_eq               -0.078157  0.842047            0.829701
# suma_tarjetas                0.074793 -0.363984           -0.364304
# tamaño_plantilla            -0.345574 -0.034016           -0.195935
# edad_media_jug               1.000000  0.053586            0.102828
# valor_eq                     0.053586  1.000000            0.979720
# valor_med_merc_jug           0.102828  0.979720            1.000000

# %% [markdown]
# ***A modo de CONCLUSION esta gráfica permite AFIRMAR en gran medida la HIPOTESIS PRINCIPAL.***
#
# ***Se observa un alto grado de correlación (0.842047) entre la valoración deportiva y económica de los clubes de las ligas más importantes de Europa.***
